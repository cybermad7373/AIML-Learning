# %%
# !pip install numpy openpyxl pandas pyarrow pyjanitor ipykernel
# !pip install --user numpy openpyxl pandas pyarrow pyjanitor ipykernel  (use this in case of any permission issue)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns = ["A","B","C"], index = ["a","b","c"])
print(df.head()) # top 5 rows ig
print(df.tail()) # last 5 rows ig
# Out:
#    A  B  C
# a  1  2  3
# b  4  5  6
# c  7  8  9
#    A  B  C
# a  1  2  3
# b  4  5  6
# c  7  8  9

# %%
print(df.index)  
print(df.index.tolist())
print(df.columns)
print(df.columns.tolist())
# Out:
# Index(['a', 'b', 'c'], dtype='object')
# ['a', 'b', 'c']
# Index(['A', 'B', 'C'], dtype='object')
# ['A', 'B', 'C']

# %%
print(df.info())
print("=============================================")
print(df.describe())
print("=============================================")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, a to c
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes
# None
# ...
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0
# ...

# %% [markdown]
# #### Loading Dataframs from files

# %%
coffee = pd.read_csv('coffee_sales.csv')

# %%
results = pd.read_parquet('results.parquet')

# %%
olympics_data = pd.read_excel('olympics-data.xlsx')

# %%
bios = pd.read_csv('bios.csv')

# %% [markdown]
# #### Accessing Data with Pandas

# %%
coffee.head()
# coffee   # shows the entire data
coffee.sample(random_state = 1)   # gets random values     # random_state is like seed which don't change the value
# Out:
#        Day Coffee Type  Units Sold
# 3  Tuesday       Latte          20

# %%
coffee.loc[[1,2,5,10]]  # can use slicing also
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 5   Wednesday       Latte          25
# 10   Saturday    Espresso          45

# %%
coffee.loc[[1,2,5],["Day","Units Sold"]]
# Out:
#          Day  Units Sold
# 1     Monday          15
# 2    Tuesday          30
# 5  Wednesday          25

# %%
coffee.iloc[[1,2,5],[1,2]]    #iloc use index to get the data
# Out:
#   Coffee Type  Units Sold
# 1       Latte          15
# 2    Espresso          30
# 5       Latte          25

# %%
coffee.loc[1,"Units Sold"] = 100

# %%
coffee.loc[1]
# Out:
# Day            Monday
# Coffee Type     Latte
# Units Sold        100
# Name: 1, dtype: object

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte         100
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.Day   # coffee["Day"]     dot symtax can be used only fro the single word
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee.sort_values(["Units Sold","Coffee Type"], ascending = False)
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte         100
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 7    Thursday       Latte          30
# 2     Tuesday    Espresso          30
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25
# 3     Tuesday       Latte          20

# %%
for index, row in coffee.iterrows():
    print(index, row["Units Sold"])
# Out:
# 0 25
# 1 100
# 2 30
# 3 20
# 4 35
# 5 25
# 6 40
# 7 30
# 8 45
# 9 35
# 10 45
# 11 35
# 12 45
# 13 35

# %% [markdown]
# ### Filtering Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios[bios['height_cm']> 215] [ ["name","height_cm" , "weight_kg"]]
# bios.loc[bios['height_cm']> 215, ["name","height_cm" , "weight_kg"]]                       

# both works fine
# Out:
#                          name  height_cm  weight_kg
# 5089       Viktor Pankrashkin      220.0      112.0
# 5583     Paulinho Villas Boas      217.0      106.0
# 5673           Gunther Behnke      221.0      114.0
# 5716                 Uwe Blab      218.0      110.0
# 5781           Tommy Burleson      223.0      102.0
# 5796            Andy Campbell      218.0       93.0
# 6223              Lars Hansen      216.0      105.0
# 6270              Hu Zhangbao      216.0      135.0
# 6409         Sergey Kovalenko      216.0      111.0
# 6420            Jānis Krūmiņš      218.0      141.0
# 6504              Luc Longley      220.0      135.0
# 6722         Shaquille O'Neal      216.0      137.0
# 6937           David Robinson      216.0      107.0
# 6978          Arvydas Sabonis      223.0      122.0
# 7074           Paulo da Silva      217.0      106.0
# 7188       Vladimir Tkachenko      220.0      110.0
# 7281         Stojko Vranković      217.0      115.0
# ...

# %%
bios[(bios['height_cm']> 215) & (bios['born_country'] == 'USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
bios[bios["name"].str.contains("Keith | patrick" , case = False)]
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 116580      117975  Elizabeth Patrick  1985-03-02     Melbourne
# 121749      123764      Jaele Patrick  1988-03-04      Lilydale
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# ...

# %%
bios[bios['born_country'].isin(["USA","NZL"])]
# Out:
#         athlete_id               name   born_date      born_city  born_region  \
# 54              55      Monique Javer  1967-07-22     Burlingame   California
# 960            964   Xóchitl Escobedo  1968-09-17    West Covina   California
# 961            965  Angélica Gavaldón  1973-10-03      El Centro   California
# 1034          1041   Belinda Cordwell  1965-09-21     Wellington   Wellington
# 1035          1042      Tammy Jenkins  1971-08-26       Kawakawa    Northland
# ...            ...                ...         ...            ...          ...
# 145445      149168     Kristen Santos  1994-11-02      Fairfield  Connecticut
# 145446      149169   Corinne Stoddard  2001-08-15        Seattle   Washington
# 145454      149180      Anna Hoffmann  2000-03-28        Madison    Wisconsin
# 145457      149183     Alix Wilkinson  2000-08-02  Mammoth Lakes   California
# 145468      149195  Justin Abdelkader  1987-02-25       Muskegon     Michigan
#
# ...

# %%
bios.query('born_country=="USA" and born_region== "California"')
# Out:
#         athlete_id               name   born_date         born_city  \
# 54              55      Monique Javer  1967-07-22        Burlingame
# 960            964   Xóchitl Escobedo  1968-09-17       West Covina
# 961            965  Angélica Gavaldón  1973-10-03         El Centro
# 1345          1352         Laura Berg  1975-01-06  Santa Fe Springs
# 1346          1353       Gillian Boxx  1973-09-01           Fontana
# ...            ...                ...         ...               ...
# 145383      149106     Tyler Wallasch  1994-06-08       Los Angeles
# 145387      149110          Alysa Liu  2005-08-08            Clovis
# 145402      149125    Brendan Brisson  2001-10-22   Manhattan Beach
# 145430      149153       Robert Burns  1990-11-11      Mount Shasta
# 145457      149183     Alix Wilkinson  2000-08-02     Mammoth Lakes
#
#        born_region born_country            NOC  height_cm  weight_kg died_date
# ...

# %% [markdown]
# ### Adding and Removing Elements

# %%
coffee.sample()
# Out:
#        Day Coffee Type  Units Sold
# 3  Tuesday       Latte          20

# %%
coffee_new = coffee.copy()
coffee_new['price'] = 0

# %%
coffee_new.sample()
# Out:
#          Day Coffee Type  Units Sold  price
# 5  Wednesday       Latte          25      0

# %%
coffee_new['new_price'] = np.where(coffee_new["Coffee Type"] == "Espresso",3.99,5.99)

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25      0       3.99
# 1      Monday       Latte          15      0       5.99
# 2     Tuesday    Espresso          30      0       3.99
# 3     Tuesday       Latte          20      0       5.99
# 4   Wednesday    Espresso          35      0       3.99
# 5   Wednesday       Latte          25      0       5.99
# 6    Thursday    Espresso          40      0       3.99
# 7    Thursday       Latte          30      0       5.99
# 8      Friday    Espresso          45      0       3.99
# 9      Friday       Latte          35      0       5.99
# 10   Saturday    Espresso          45      0       3.99
# 11   Saturday       Latte          35      0       5.99
# 12     Sunday    Espresso          45      0       3.99
# 13     Sunday       Latte          35      0       5.99

# %%
coffee_new.drop(columns = ['price'], inplace=True)

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99
