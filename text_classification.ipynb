# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
#!pip install numpy == 1.16.1

# %%
data = keras.datasets.imdb

# %%
(train_data, train_labels), (test_data,test_labels) = data.load_data(num_words = 88000)

# %%
print(train_data[1])
# Out:
# [1, 194, 1153, 194, 8255, 78, 228, 5, 6, 1463, 4369, 5012, 134, 26, 4, 715, 8, 118, 1634, 14, 394, 20, 13, 119, 954, 189, 102, 5, 207, 110, 3103, 21, 14, 69, 188, 8, 30, 23, 7, 4, 249, 126, 93, 4, 114, 9, 2300, 1523, 5, 647, 4, 116, 9, 35, 8163, 4, 229, 9, 340, 1322, 4, 118, 9, 4, 130, 4901, 19, 4, 1002, 5, 89, 29, 952, 46, 37, 4, 455, 9, 45, 43, 38, 1543, 1905, 398, 4, 1649, 26, 6853, 5, 163, 11, 3215, 10156, 4, 1153, 9, 194, 775, 7, 8255, 11596, 349, 2637, 148, 605, 15358, 8003, 15, 123, 125, 68, 23141, 6853, 15, 349, 165, 4362, 98, 5, 4, 228, 9, 43, 36893, 1157, 15, 299, 120, 5, 120, 174, 11, 220, 175, 136, 50, 9, 4373, 228, 8255, 5, 25249, 656, 245, 2350, 5, 4, 9837, 131, 152, 491, 18, 46151, 32, 7464, 1212, 14, 9, 6, 371, 78, 22, 625, 64, 1382, 9, 8, 168, 145, 23, 4, 1690, 15, 16, 4, 1355, 5, 28, 6, 52, 154, 462, 33, 89, 78, 285, 16, 145, 95]

# %%
word_index = data.get_word_index()
word_index = {k: (v+3) for k,v in word_index.items()}
word_index["<PAD>"] = 0
word_index["<START>"] = 1
word_index["<UNK>"] = 2
word_index["<UNUSED>"] = 3

# %%
reverse_word_index = dict([(value,key) for (key, value) in word_index.items()])

# %%
def decode_review(text):
    return " ".join([reverse_word_index.get(i,"?") for i in text])

# %%
print(decode_review(test_data[0]))
# Out:
# <START> please give this one a miss br br kristy swanson and the rest of the cast rendered terrible performances the show is flat flat flat br br i don't know how michael madison could have allowed this one on his plate he almost seemed to know this wasn't going to work out and his performance was quite lacklustre so all you madison fans give this a miss

# %%
print(len(test_data[0]),len(test_data[1]))
# Out:
# 68 260

# %%
train_data = keras.preprocessing.sequence.pad_sequences(train_data, value=word_index["<PAD>"], padding="post", maxlen=250)
test_data = keras.preprocessing.sequence.pad_sequences(test_data, value=word_index["<PAD>"], padding="post", maxlen=250)

# %%
print(len(test_data),len(test_data))
# Out:
# 25000 25000

# %% [markdown]
# ##### model

# %%
model = keras.Sequential()
model.add(keras.layers.Embedding(88000,16))
model.add(keras.layers.GlobalAveragePooling1D()) 
model.add(keras.layers.Dense(16,activation = 'relu'))
model.add(keras.layers.Dense(1,activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling1d_1           │ ?                           │               0 │
# │ (GlobalAveragePooling1D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
x_val = train_data[:10000]
x_train  = train_data[10000:]

y_val = train_labels[:10000]
y_train  = train_labels[10000:]

# %%
fitModel = model.fit(x_train,y_train,epochs = 40, batch_size = 512, validation_data = (x_val,y_val),verbose = 1)
# Out:
# Epoch 1/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.5743 - loss: 0.6915 - val_accuracy: 0.7078 - val_loss: 0.6822
# Epoch 2/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7263 - loss: 0.6761 - val_accuracy: 0.7160 - val_loss: 0.6581
# Epoch 3/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7537 - loss: 0.6464 - val_accuracy: 0.7705 - val_loss: 0.6204
# Epoch 4/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7850 - loss: 0.6025 - val_accuracy: 0.7716 - val_loss: 0.5726
# Epoch 5/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7989 - loss: 0.5497 - val_accuracy: 0.7698 - val_loss: 0.5299
# Epoch 6/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8159 - loss: 0.4935 - val_accuracy: 0.8173 - val_loss: 0.4755
# Epoch 7/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8499 - loss: 0.4414 - val_accuracy: 0.8075 - val_loss: 0.4455
# Epoch 8/40
# ...

# %%
results = model.evaluate(test_data,test_labels)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8795 - loss: 0.3112

# %%
print(results)
# Out:
# [0.31830066442489624, 0.8769999742507935]

# %%
# model.save("./models/text_class/model.h5")               #saving the model

# %%
model = keras.models.load_model("./models/text_class/model.h5")        #loading the saved model
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Select a test review
test_review = test_data[0]

# Ensure input has correct shape for model prediction
predict = model.predict(np.array([test_review]))

# Function to decode a review from word indices
def decode_review(text):
    reverse_word_index = {v: k for k, v in word_index.items()}  # Reverse dictionary
    return " ".join([reverse_word_index.get(i, "<UNK>") for i in text])

# Print decoded review and prediction
print("Review:")
print(decode_review(test_review))
print("Prediction Score: {:.4f}".format(predict[0][0]))  # Format for clarity

# Ensure test_labels exists and print actual sentiment
if 'test_labels' in globals():  
    print("Actual Sentiment: " + str(test_labels[0]))

# Ensure results variable exists before printing
if 'results' in globals():
    print("Evaluation Results:", results)
else:
    results = model.evaluate(test_data, test_labels)
    print("Evaluation Results:", results)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[109], line 5
#       2 test_review = test_data[0]
#       4 # Ensure input has correct shape for model prediction
# ----> 5 predict = model.predict(np.array([test_review]))
#       7 # Function to decode a review from word indices
#       8 def decode_review(text):
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ...
